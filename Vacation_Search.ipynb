# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np
# Import the API key.
from config import g_key

# %%
# school_data_to_load = "Resources/schools_complete.csv"
city_data_df = "WeatherPy_Challenge.csv"

# %%
# school_data_df = pd.read_csv(school_data_to_load)
#school_data_df
city_info_df = pd.read_csv("WeatherPy_Challenge.csv")

# %%
city_info_df
# Out:
#      City_ID                     City Country                 Date    Lat  \
# 0          0                Cape Town      ZA  2020-05-01 23:11:43 -33.93
# 1          1                 Bengkulu      ID  2020-05-01 23:11:43  -3.80
# 2          2                    Kapaa      US  2020-05-01 23:11:43  22.08
# 3          3           Ribeira Grande      PT  2020-05-01 23:11:43  38.52
# 4          4              Yellowknife      CA  2020-05-01 23:11:39  62.46
# ..       ...                      ...     ...                  ...    ...
# 561      561                   Agadez      NE  2020-05-01 23:13:53  19.75
# 562      562  Rodionovo-Nesvetayskaya      RU  2020-05-01 23:13:54  47.61
# 563      563                     Nawa      IN  2020-05-01 23:13:54  27.02
# 564      564                Raudeberg      NO  2020-05-01 23:13:54  61.99
# 565      565                   Padang      ID  2020-05-01 23:13:55  -0.95
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_info_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Get the rain amount.
rain = city_info_df["Rain inches (last 3 hrs)"]
inches = []
for inch in rain:
    inches.append(min(inch, 0))

# %%
# Get the snow amount
snow = city_info_df["Snow inches (last 3 hrs)"]
inches = []
for inch in snow:
    inches.append(min(inch, 0))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
rain = input("Do you want it to rain?(yes/no)")
snow = input("Do you want it snow?(yes/no)")
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 80
# Do you want it to rain?(yes/no)no
# Do you want it snow?(yes/no)no

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_info_df.loc[(city_info_df["Max Temp"] <= max_temp) & \
                                       (city_info_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 1         1        Bengkulu      ID  2020-05-01 23:11:43  -3.80  102.27
# 2         2           Kapaa      US  2020-05-01 23:11:43  22.08 -159.32
# 3         3  Ribeira Grande      PT  2020-05-01 23:11:43  38.52  -28.70
# 5         5        Mahanoro      MG  2020-05-01 23:11:45 -19.90   48.80
# 8         8          Castro      BR  2020-05-01 23:11:45 -24.79  -50.01
# 12       12            Hilo      US  2020-05-01 23:11:46  19.73 -155.09
# 14       14             Vao      NC  2020-05-01 23:11:46 -22.67  167.48
# 16       16         Tsuruga      JP  2020-05-01 23:11:47  35.65  136.06
# 21       21     Port Alfred      ZA  2020-05-01 23:11:48 -33.59   26.89
# 27       27         Rikitea      PF  2020-05-01 23:11:50 -23.12 -134.97
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 1      77.22        85         100       10.07     overcast clouds
# ...

# %%
preferred_cities_df.count()
# Out:
# City_ID                     240
# City                        240
# Country                     234
# Date                        240
# Lat                         240
# Lng                         240
# Max Temp                    240
# Humidity                    240
# Cloudiness                  240
# Wind Speed                  240
# Current Description         240
# Rain inches (last 3 hrs)    240
# Snow inches (last 3 hrs)    240
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#              City Country  Max Temp    Lat     Lng Hotel Name
# 1        Bengkulu      ID     77.22  -3.80  102.27
# 2           Kapaa      US     78.80  22.08 -159.32
# 3  Ribeira Grande      PT     62.89  38.52  -28.70
# 5        Mahanoro      MG     70.90 -19.90   48.80
# 8          Castro      BR     61.18 -24.79  -50.01

# %%
# Set parameters to search for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 1         Bengkulu      ID     77.22  -3.80  102.27
# 2            Kapaa      US     78.80  22.08 -159.32
# 3   Ribeira Grande      PT     62.89  38.52  -28.70
# 5         Mahanoro      MG     70.90 -19.90   48.80
# 8           Castro      BR     61.18 -24.79  -50.01
# 12            Hilo      US     79.00  19.73 -155.09
# 14             Vao      NC     76.60 -22.67  167.48
# 16         Tsuruga      JP     66.00  35.65  136.06
# 21     Port Alfred      ZA     64.00 -33.59   26.89
# 27         Rikitea      PF     79.38 -23.12 -134.97
#
#                                 Hotel Name
# 1                     Grage Hotel Bengkulu
# 2   Sheraton Kauai Resort at Coconut Beach
# 3                      Quinta da Meia Eira
# 5                          Hôtel Mon Désir
# 8                           CHACARA BAILLY
# 12                     Hilo Hawaiian Hotel
# 14                         Hotel Kou-Bugny
# ...

# %%
# Add pop up markers
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
cities = hotel_df["City"]
country = hotel_df["Country"]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotel_final_df = pd.DataFrame(hotel_df)
hotel_final_df.head()
# Out:
#              City Country  Max Temp    Lat     Lng  \
# 1        Bengkulu      ID     77.22  -3.80  102.27
# 2           Kapaa      US     78.80  22.08 -159.32
# 3  Ribeira Grande      PT     62.89  38.52  -28.70
# 5        Mahanoro      MG     70.90 -19.90   48.80
# 8          Castro      BR     61.18 -24.79  -50.01
#
#                                Hotel Name
# 1                    Grage Hotel Bengkulu
# 2  Sheraton Kauai Resort at Coconut Beach
# 3                     Quinta da Meia Eira
# 5                         Hôtel Mon Désir
# 8                          CHACARA BAILLY

# %%
#Save new DataFrame as a CSV file- WeatherPy_Challenge.csv 
output_data_file = "WeatherPy_vacation.csv"
# Export the City_Data into a CSV.)
hotel_final_df.to_csv(output_data_file, index_label="City_ID")
