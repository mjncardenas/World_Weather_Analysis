# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np
# Import the API key.
from config import g_key

# %%
# school_data_to_load = "Resources/schools_complete.csv"
hotel_final_df = "WeatherPy_vacation.csv"

# %%
hotel_info_df = pd.read_csv("WeatherPy_vacation.csv")

# %%
hotel_info_df.head(50)
# Out:
#     City_ID                  City Country  Max Temp    Lat     Lng  \
# 0         1              Bengkulu      ID     77.22  -3.80  102.27
# 1         2                 Kapaa      US     78.80  22.08 -159.32
# 2         3        Ribeira Grande      PT     62.89  38.52  -28.70
# 3         5              Mahanoro      MG     70.90 -19.90   48.80
# 4         8                Castro      BR     61.18 -24.79  -50.01
# 5        12                  Hilo      US     79.00  19.73 -155.09
# 6        14                   Vao      NC     76.60 -22.67  167.48
# 7        16               Tsuruga      JP     66.00  35.65  136.06
# 8        21           Port Alfred      ZA     64.00 -33.59   26.89
# 9        27               Rikitea      PF     79.38 -23.12 -134.97
# 10       29                 Moron      AR     63.00 -34.65  -58.62
# 11       36               Quesnel      CA     62.60  53.00 -122.50
# 12       37            Sao Filipe      CV     77.16  14.90  -24.50
# ...

# %%
# df.groupby(["state", "gender"], as_index=False)["last_name"]
vacation_df = hotel_info_df.groupby("Country")

# %%
# by_state.get_group("PA")
vacation_df.get_group("BR")
# Out:
#      City_ID                      City Country  Max Temp    Lat    Lng  \
# 4          8                    Castro      BR     61.18 -24.79 -50.01
# 19        48                  Cidreira      BR     62.87 -30.18 -50.21
# 21        54         Sao Joao Da Barra      BR     72.37 -21.64 -41.05
# 33        79      Santo Antonio Do Ica      BR     78.94  -3.10 -67.94
# 51       126           Arraial Do Cabo      BR     74.28 -22.97 -42.03
# 57       137              Pouso Alegre      BR     61.65 -22.23 -45.94
# 64       152                Coromandel      BR     61.95 -18.47 -47.20
# 82       188                 Paranaiba      BR     70.18 -19.68 -51.19
# 100      236     Senador Jose Porfirio      BR     77.70  -2.59 -51.95
# 102      247  Sao Jose Da Coroa Grande      BR     79.59  -8.90 -35.15
# 108      260                Vila Velha      BR     77.00 -20.33 -40.29
# 109      262                 Piacabucu      BR     78.57 -10.41 -36.43
# ...

# %%
import gmaps
import gmaps.datasets
gmaps.configure(g_key)

# Latitude-longitude pairs
Belmonte = (-15.86, -38.88)
Niquelandia = (-14.47, -48.46)
Coromandel = (-18.47, -47.20)
Caravelas = (-17.71,-39.25)
fig = gmaps.figure()
Belmonte2Caravelas = gmaps.directions_layer(Belmonte, Caravelas)
fig.add_layer(Belmonte2Caravelas)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
Belmonte_df = hotel_info_df[hotel_info_df["City"] == "Belmonte"]
Belmonte_df
# Out:
#      City_ID      City Country  Max Temp    Lat    Lng  \
# 121      296  Belmonte      BR      77.0 -15.86 -38.88
#
#                       Hotel Name
# 121  Pousada Monte Carmelo O Pão

# %%
Niquelandia_df = hotel_info_df[hotel_info_df["City"] == "Niquelandia"]
Niquelandia_df
# Out:
#      City_ID         City Country  Max Temp    Lat    Lng   Hotel Name
# 188      438  Niquelandia      BR     70.43 -14.47 -48.46  Hotel Suinã

# %%
Coromandel_df = hotel_info_df[hotel_info_df["City"] == "Coromandel"]
Coromandel_df
# Out:
#     City_ID        City Country  Max Temp    Lat   Lng         Hotel Name
# 64      152  Coromandel      BR     61.95 -18.47 -47.2  Hotel Dona Adélia

# %%
Caravelas_df = hotel_info_df[hotel_info_df["City"] == "Caravelas"]
Caravelas_df
# Out:
#      City_ID       City Country  Max Temp    Lat    Lng  \
# 204      475  Caravelas      BR     74.28 -17.71 -39.25
#
#                  Hotel Name
# 204  Pousada dos Navegantes

# %%
#school_data_complete_df = pd.merge(stdent_data_df, school_data_df)
Belmonte_Niquelandia_df = pd. merge(Belmonte_df, Niquelandia_df, how="outer")
Belmonte_Niquelandia_df
# Out:
#    City_ID         City Country  Max Temp    Lat    Lng  \
# 0      296     Belmonte      BR     77.00 -15.86 -38.88
# 1      438  Niquelandia      BR     70.43 -14.47 -48.46
#
#                     Hotel Name
# 0  Pousada Monte Carmelo O Pão
# 1                  Hotel Suinã

# %%
BelNique_Coro_df = pd. merge(Belmonte_Niquelandia_df, Coromandel_df, how="outer")
BelNique_Coro_df
# Out:
#    City_ID         City Country  Max Temp    Lat    Lng  \
# 0      296     Belmonte      BR     77.00 -15.86 -38.88
# 1      438  Niquelandia      BR     70.43 -14.47 -48.46
# 2      152   Coromandel      BR     61.95 -18.47 -47.20
#
#                     Hotel Name
# 0  Pousada Monte Carmelo O Pão
# 1                  Hotel Suinã
# 2            Hotel Dona Adélia

# %%
complete_itinerary_df = pd. merge(BelNique_Coro_df, Caravelas_df, how="outer")
complete_itinerary_df
# Out:
#    City_ID         City Country  Max Temp    Lat    Lng  \
# 0      296     Belmonte      BR     77.00 -15.86 -38.88
# 1      438  Niquelandia      BR     70.43 -14.47 -48.46
# 2      152   Coromandel      BR     61.95 -18.47 -47.20
# 3      475    Caravelas      BR     74.28 -17.71 -39.25
#
#                     Hotel Name
# 0  Pousada Monte Carmelo O Pão
# 1                  Hotel Suinã
# 2            Hotel Dona Adélia
# 3       Pousada dos Navegantes

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
complete_itinerary_df = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
fig = gmaps.figure()
Belmonte2Caravelas_via_Paranaiba = gmaps.directions_layer(
        Belmonte, Caravelas, waypoints=[Niquelandia, Coromandel],
        travel_mode='DRIVING')
fig.add_layer(Belmonte2Caravelas_via_Paranaiba)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
